# %%
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.datasets import mnist
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
wgan_images = []
labels = []

# %%
def pca(real, fake, label):
  print("plot for label: ", label)
  pca1 = PCA(n_components=2)
  pca2 = PCA(n_components=2)

  real_pca = pca1.fit_transform(real)
  fake_pca = pca2.fit_transform(fake)

  # Plot the first PCA scatter plot
  plt.scatter(real_pca[:, 0], real_pca[:, 1], color='blue', label='Real')

  # Plot the second PCA scatter plot
  plt.scatter(fake_pca[:, 0], fake_pca[:, 1], color='red', label='Fake')

  # Add labels and title
  plt.xlabel('Principal Component 1')
  plt.ylabel('Principal Component 2')
  plt.title('PCA Scatter plots of real and fake')

  # Add legend
  plt.legend()

  # Show plot
  plt.show()

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
test_images = test_images/255

# %%
indices_of_zeros = np.where(test_labels == 0)[0]
images_of_zeros = test_images[indices_of_zeros]
images_of_zeros = images_of_zeros.reshape(-1, 784)
images_of_zeros.shape
# Out:
# (980, 784)

# %%
data_0 = np.load("label_0_wgan.npz", allow_pickle=True)
images_data_0 = data_0["data"]
images_data_0 = images_data_0[:len(images_of_zeros)]
images_data_0 = images_data_0.reshape(-1, 784)
labels_0 = [0]*len(images_data_0)
images_data_0.shape
# Out:
# (980, 784)

# %%
pca(images_data_0, images_of_zeros, 0)
# Out:
# plot for label:  0

# %%
indices_of_ones = np.where(test_labels == 1)[0]
images_of_ones = test_images[indices_of_ones]
images_of_ones = images_of_ones.reshape(-1, 784)
images_of_ones.shape
# Out:
# (1135, 784)

# %%
data_1 = np.load("label_1_wgan.npz", allow_pickle=True)
images_data_1 = data_1["data"]
images_data_1 = images_data_1[:len(images_of_ones)]
images_data_1 = images_data_1.reshape(-1, 784)
labels_1 = [1]*len(images_data_1)
wgan_images.append(images_data_1)
labels.append(labels_1)
images_data_1.shape
# Out:
# (1135, 784)

# %%
pca(images_data_1, images_of_ones, 1)
# Out:
# plot for label:  1

# %%
indices_of_twos = np.where(test_labels == 2)[0]
images_of_twos = test_images[indices_of_twos]
images_of_twos = images_of_twos.reshape(-1, 784)
images_of_twos.shape
# Out:
# (1032, 784)

# %%
data_2 = np.load("label_2_wgan.npz", allow_pickle=True)
images_data_2 = data_2["data"]
images_data_2 = images_data_2[:len(images_of_twos)]
images_data_2 = images_data_2.reshape(-1, 784)
labels_2 = [2]*len(images_data_2)
wgan_images.append(images_data_2)
labels.append(labels_2)
images_data_2.shape
# Out:
# (1010, 784)

# %%
pca(images_data_2, images_of_twos, 2)
# Out:
# plot for label:  2

# %%
indices_of_threes = np.where(test_labels == 3)[0]
images_of_threes = test_images[indices_of_threes]
images_of_threes = images_of_threes.reshape(-1, 784)
images_of_threes.shape
# Out:
# (1010, 784)

# %%
import numpy as np
data_3 = np.load("label_3_wgan.npz", allow_pickle=True)
images_data_3 = data_3["data"]
images_data_3 = images_data_3[:len(images_of_threes)]
images_data_3 = images_data_3.reshape(-1, 784)
labels_3 = [3]*len(images_data_3)
wgan_images.append(images_data_3)
labels.append(labels_3)
images_data_3.shape
# Out:
# (1010, 784)

# %%
pca(images_data_3, images_of_threes, 3)
# Out:
# plot for label:  3

# %%
indices_of_fours = np.where(test_labels == 4)[0]
images_of_fours = test_images[indices_of_fours]
images_of_fours = images_of_fours.reshape(-1, 784)
images_of_fours.shape
# Out:
# (982, 784)

# %%
data_4 = np.load("label_4_wgan.npz", allow_pickle=True)
images_data_4 = data_4["data"]
images_data_4 = images_data_4[:len(images_of_fours)]
images_data_4 = images_data_4.reshape(-1, 784)
labels_4 = [4]*len(images_data_4)
wgan_images.append(images_data_4)
labels.append(labels_4)
images_data_4.shape
# Out:
# (982, 784)

# %%
pca(images_data_4, images_of_fours, 4)
# Out:
# plot for label:  4

# %%
indices_of_fives = np.where(test_labels == 5)[0]
images_of_fives = test_images[indices_of_fives]
images_of_fives = images_of_fives.reshape(-1, 784)
images_of_fives.shape
# Out:
# (892, 784)

# %%
data_5 = np.load("label_5_wgan.npz", allow_pickle=True)
images_data_5 = data_5["data"]
images_data_5 = images_data_5[:len(images_of_fives)]
images_data_5 = images_data_5.reshape(-1, 784)
labels_5 = [5]*len(images_data_5)
wgan_images.append(images_data_5)
labels.append(labels_5)
images_data_5.shape
# Out:
# (892, 784)

# %%
pca(images_data_5, images_of_fives, 5)
# Out:
# plot for label:  5

# %%
indices_of_sixes = np.where(test_labels == 6)[0]
images_of_sixes = test_images[indices_of_sixes]
images_of_sixes = images_of_sixes.reshape(-1, 784)
images_of_sixes.shape
# Out:
# (958, 784)

# %%
data_6 = np.load("label_6_wgan.npz", allow_pickle=True)
images_data_6 = data_6["data"]
images_data_6 = images_data_6[:len(images_of_sixes)]
images_data_6 = images_data_6.reshape(-1, 784)
labels_6 = [6]*len(images_data_6)
wgan_images.append(images_data_6)
labels.append(labels_6)
images_data_6.shape
# Out:
# (958, 784)

# %%
pca(images_data_6, images_of_sixes, 6)
# Out:
# plot for label:  6

# %%
indices_of_sevens = np.where(test_labels == 7)[0]
images_of_sevens = test_images[indices_of_sevens]
images_of_sevens = images_of_sevens.reshape(-1, 784)
images_of_sevens.shape
# Out:
# (1028, 784)

# %%
data_7 = np.load("label_7_wgan.npz", allow_pickle=True)
images_data_7 = data_7["data"]
images_data_7 = images_data_7[:len(images_of_sevens)]
images_data_7 = images_data_7.reshape(-1, 784)
labels_7 = [7]*len(images_data_7)
wgan_images.append(images_data_7)
labels.append(labels_7)
images_data_7.shape
# Out:
# (1028, 784)

# %%
pca(images_data_7, images_of_sevens, 7)
# Out:
# plot for label:  7

# %%
indices_of_eights = np.where(test_labels == 8)[0]
images_of_eights = test_images[indices_of_eights]
images_of_eights = images_of_eights.reshape(-1, 784)
images_of_eights.shape
# Out:
# (974, 784)

# %%
data_8 = np.load("label_8_wgan.npz", allow_pickle=True)
images_data_8 = data_8["data"]
images_data_8 = images_data_8[:len(images_of_eights)]
images_data_8 = images_data_8.reshape(-1, 784)
labels_8 = [8]*len(images_data_8)
wgan_images.append(images_data_8)
labels.append(labels_8)
images_data_8.shape
# Out:
# (974, 784)

# %%
pca(images_data_8, images_of_eights, 8)
# Out:
# plot for label:  8

# %%
indices_of_nines = np.where(test_labels == 9)[0]
images_of_nines = test_images[indices_of_nines]
images_of_nines = images_of_nines.reshape(-1, 784)
images_of_nines.shape
# Out:
# (1009, 784)

# %%
data_9 = np.load("label_9_wgan.npz", allow_pickle=True)
images_data_9 = data_9["data"]
images_data_9 = images_data_9[:len(images_of_nines)]
images_data_9 = images_data_9.reshape(-1, 784)
labels_9 = [9]*len(images_data_9)
wgan_images.append(images_data_9)
labels.append(labels_9)
images_data_9.shape
# Out:
# (1009, 784)

# %%
pca(images_data_9, images_of_nines, 9)
# Out:
# plot for label:  9

# %%
# wgan_images = np.array(wgan_images)
concatenated_array = np.concatenate((images_data_0, images_data_1, images_data_2,
                                     images_data_3, images_data_4, images_data_5,
                                     images_data_6, images_data_7, images_data_8,
                                     images_data_9), axis=0)
concatenated_labels = np.concatenate((labels_0, labels_1, labels_2,
                                     labels_3, labels_4, labels_5,
                                     labels_6, labels_7, labels_8,
                                     labels_9), axis=0)
print(concatenated_array.shape)
print(concatenated_labels.shape)
# Out:
# (9978, 784)
# (9978,)

# %%
print(len(labels))
# Out:
# 9

# %%
pca = PCA(n_components=2)
X_reduced = pca.fit_transform(concatenated_array)

import seaborn as sns
plt.figure(figsize=(10, 8))
sns.scatterplot(x=X_reduced[:, 0], y=X_reduced[:, 1], hue=concatenated_labels, palette='tab10', legend='full', alpha=0.8)
plt.title('MNIST dataset visualization using PCA fake examples')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()
